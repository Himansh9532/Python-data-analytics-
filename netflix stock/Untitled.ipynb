# %% [markdown]
# # Netflix STOCK PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
df=pd.read_csv("NFLX Stock Pridiction.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     05-02-2018  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     06-02-2018  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     07-02-2018  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     08-02-2018  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     09-02-2018  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  31-01-2022  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  01-02-2022  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  02-02-2022  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  03-02-2022  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  04-02-2022  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %%
df.head(5)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
sns.set(rc={"figure.figsize":(10,5)})

# %%
df.head(7)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5 2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6 2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y", errors='coerce')

# %%
print(type("Date"))
# Out:
# <class 'str'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   datetime64[ns]
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 55.3 KB

# %%
df = df.set_index("Date")

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900

# %% [markdown]
# # 1. Volume of Stock Traded

# %%
sns.lineplot(x = df.index , y = df["Volume"], label = "volume")
plt.title ("volume ")
# Out:
# Text(0.5, 1.0, 'volume ')

# %% [markdown]
# # 2.Netflix Stock Price - High , Open , Close

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# ...

# %%
df.plot(y = ["High","Close" , "Open"])
plt.title("Netflix stock price")
# Out:
# Text(0.5, 1.0, 'Netflix stock price')

# %% [markdown]
# # 3. netflix stock price - day , month , yearwise

# %%
fig , (ax1,ax2,ax3) = plt.subplots(3,figsize = (15,10))
df.groupby(df.index.day).mean().plot(y = "Volume" , ax = ax1 , xlabel = "Day")
df.groupby(df.index.month).mean().plot(y = "Volume" , ax = ax2 , xlabel = "Month")
df.groupby(df.index.year).mean().plot(y = "Volume" , ax = ax3 , xlabel = "Year")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # 4. top 5 dates with highest stock price

# %%
a = df.sort_values(by = "High" , ascending = False)

# %%
a
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-11-17  690.000000  700.989990  686.090027  691.690002  691.690002
# 2021-11-19  692.349976  694.159973  675.000000  678.799988  678.799988
# 2021-11-18  691.609985  691.739990  679.739990  682.020020  682.020020
# 2021-10-29  673.059998  690.969971  671.239990  690.309998  690.309998
# 2021-11-01  689.059998  689.969971  676.539978  681.169983  681.169983
# ...                ...         ...         ...         ...         ...
# 2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 2018-12-27  250.110001  255.589996  240.100006  255.570007  255.570007
# 2018-12-26  233.919998  254.500000  231.229996  253.669998  253.669998
# 2018-12-24  242.000000  250.649994  233.679993  233.880005  233.880005
#
#               Volume
# Date
# 2021-11-17   2732800
# 2021-11-19   2613700
# 2021-11-18   2012900
# ...

# %%
a["High"].head(5)
# Out:
# Date
# 2021-11-17    700.989990
# 2021-11-19    694.159973
# 2021-11-18    691.739990
# 2021-10-29    690.969971
# 2021-11-01    689.969971
# Name: High, dtype: float64

# %%
b = df.sort_values(by = "Low" , ascending = True)

# %%
b["Low"].head(5)
# Out:
# Date
# 2018-12-24    233.679993
# 2018-12-26    231.229996
# 2018-12-27    240.100006
# 2018-02-09    236.110001
# 2018-02-12    249.000000
# Name: Low, dtype: float64

# %%
fig,axes = plt.subplots(nrows = 1 , ncols = 2, sharex = True , figsize = (20,9))
fig.suptitle("High and Low Stock Per Period Of Time")
sns.lineplot(ax = axes[0], y = df["High"] , x = df.index, color = "green")
sns.lineplot(ax = axes[1] , y = df["Low"] , x = df.index , color = "red" )
# Out:
# <Axes: xlabel='Date', ylabel='Low'>
